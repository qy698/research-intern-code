# %%
#1.查看排名

from BenchmarkTestTool import check_test_rank

check_test_rank(submitter="all", rank_by="pearson")
# Out:
# **************************************************
# BENCHMARK测试榜排名:
# **************************************************
# *指标说明:
# pearson:皮尔森相关系数
# prs_dcy:信号相关性每日衰减系数
# prs_250:最近250天（一年）的pearson均值
# sprm:序相关性，斯皮尔曼相关系数
# top30_win:信号每日前30名有正超额收益的胜率
# ac:信号自相关性
#
# 0.
# +-------------------+-----------+---------+---------------------------------------+---------+
# |    submit_time    | submitter | dataset |                comment                | pearson |
# +-------------------+-----------+---------+---------------------------------------+---------+
# | 21-03-24 07:39:41 |    WHS    | HS300V2 | factor_selection_criteria_2 & BN test |  0.0536 |
# +-------------------+-----------+---------+---------------------------------------+---------+
# +---------+---------+---------+--------+-----------+--------+
# | prs_std | prs_dcy | prs_250 |  sprm  | top30_win |   ac   |
# +---------+---------+---------+--------+-----------+--------+
# ...

# %%
from BenchmarkTestTool import submit_benchmark_test

# %%
help(submit_benchmark_test)
# Out:
# Help on function submit_benchmark_test in module BenchmarkTestTool:
#
# submit_benchmark_test(submitter, data, dataset, comment='', submit=True)
#     submitter:提交人
#     data: 模型输出，格式为:
#         [
#          [date0, stock0, score0],
#          [date1, stock1, score1],
#          [date2, stock2, score2],
#          ...
#         ]
#     dataset: 指定benchmark数据集的名字

# %%
#2.提交测试

from BenchmarkTestTool import submit_benchmark_test

'''
提交测试的数据格式如下:

submitter:提交人
data: 模型输出，格式为一个形如[[产生预测的日期, 股票, 模型分数]]的list:
    [
     [date0, stock0, score0],
     [date1, stock1, score1],
     [date2, stock2, score2],
     ...
    ]
    
    例子：
    [['3006', '2283', '0.09447305649518967'],
     ['3351', '2767', '-0.04838739335536957'],
     ['3432', '96', '-0.11213558912277222'],
     ['3540', '1', '0.1013108566403389'],
     ['3410', '2583', '-0.021173439919948578'],
     ['3271', '3082', '-0.07458115369081497'],
     ['3089', '689', '-0.16121551394462585'],
     ['3386', '3082', '0.10621000826358795'],
     ['3223', '244', '0.027103424072265625']]

dataset: 指定benchmark数据集的名字
comment: 关于本次提交的备注，建议写上模型名称或者优化点等等，帮助区分
submit: 是否正式提交。若为True，则录入到数据库，计入排名; 若为False, 则不参加排名，仅返回结果，做测试参考用
'''

data = data #请按照以上格式输入模型在test_X数据集上输出的分数
submitter = "James"
dataset = "HS300V1"
comment = 'test'
submit_benchmark_test(submitter, data, dataset, comment)
